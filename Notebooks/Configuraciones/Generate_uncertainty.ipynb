# %% [markdown]
# # Notebook to process uncertainty for inverse of temperature

# %%
import os
import numpy as np
import time
import pandas as pd

# %%
#infinite
data_path=os.path.join("C:\\Users\\MHJGuillermo\\PycharmProjects\\Doctorado\\Ising\\isingchat\\venv\\data\\regular\\infinite-size")
file_all_tc = 'regular_all_Tc.csv'
#finite
data_path=os.path.join("C:\\Users\\MHJGuillermo\\PycharmProjects\\Doctorado\\Ising\\isingchat\\venv\\data\\regular\\finite-size")
file_all_tc = 'finite_all_Tc.csv'

df_all_tc = pd.read_csv(os.path.join(data_path,file_all_tc))

#infinite
# file_all_tc_uncert = 'regular_all_Tc_uncertainty.csv'
#finite
file_all_tc_uncert = 'finite_all_Tc_uncert.csv'
df_all_tc_uncert= pd.read_csv(os.path.join(data_path,file_all_tc_uncert))

# %%
COLUMNS = ['P1.0','P1.05','P1.1','P1.2','P1.3','P1.4','P1.5','P1.6','P1.7','P1.8','P1.9','P2.0']
df_all_inv_tc_uncert=df_all_tc[['nv']]
for col in COLUMNS:
    df_all_inv_tc_uncert[col] = (df_all_tc_uncert[col]/(df_all_tc[col]**2))
# Out:
# c:\users\mhjguillermo\pycharmprojects\doctorado\ising\isingchat\venv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df_all_inv_tc_uncert
# Out:
#     nv      P1.0     P1.05      P1.1      P1.2      P1.3      P1.4      P1.5  \
# 0    2  0.001222  0.001222  0.001222  0.001222  0.001222  0.001222  0.001222
# 1    3  0.000764  0.000782  0.000800  0.000835  0.000870  0.000905  0.000938
# 2    4  0.000563  0.000585  0.000609  0.000655  0.000703  0.000751  0.000799
# 3    5  0.000450  0.000474  0.000498  0.000549  0.000602  0.000658  0.000715
# 4    6  0.000377  0.000402  0.000426  0.000479  0.000535  0.000595  0.000657
# 5    7  0.000327  0.000351  0.000376  0.000429  0.000487  0.000548  0.000614
# 6    8  0.000289  0.000313  0.000338  0.000391  0.000450  0.000512  0.000581
# 7    9  0.000261  0.000284  0.000309  0.000362  0.000420  0.000484  0.000554
# 8   10  0.000238  0.000261  0.000285  0.000337  0.000396  0.000461  0.000532
# 9   11  0.000504  0.000554  0.000609  0.000728  0.000862  0.001012  0.001178
# 10  12  0.000468  0.000518  0.000571  0.000689  0.000823  0.000974  0.001141
# 11  13       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 12  14       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 13  15       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 14  16       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 15  17       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 16  18       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 17  19       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 18  20       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 19  21       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 20  22       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 21  23       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 22  24       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 23  25       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#         P1.6      P1.7      P1.8      P1.9      P2.0
# 0   0.001222  0.001222  0.001222  0.001222  0.001222
# 1   0.000973  0.001006  0.001038  0.001070  0.001102
# 2   0.000849  0.000899  0.000948  0.000998  0.001048
# 3   0.000773  0.000833  0.000894  0.000957  0.001019
# 4   0.000722  0.000789  0.000858  0.000929  0.001002
# 5   0.000682  0.000756  0.000830  0.000909  0.000989
# 6   0.000653  0.000730  0.000810  0.000894  0.000982
# 7   0.000629  0.000709  0.000794  0.000884  0.000976
# 8   0.000609  0.000692  0.000781  0.000875  0.000973
# 9   0.001359  0.001555  0.001764  0.001989  0.002225
# 10  0.001325  0.001526  0.001742  0.001973  0.002221
# 11       NaN       NaN       NaN       NaN       NaN
# 12       NaN       NaN       NaN       NaN       NaN
# 13       NaN       NaN       NaN       NaN       NaN
# 14       NaN       NaN       NaN       NaN       NaN
# 15       NaN       NaN       NaN       NaN       NaN
# 16       NaN       NaN       NaN       NaN       NaN
# 17       NaN       NaN       NaN       NaN       NaN
# 18       NaN       NaN       NaN       NaN       NaN
# 19       NaN       NaN       NaN       NaN       NaN
# 20       NaN       NaN       NaN       NaN       NaN
# 21       NaN       NaN       NaN       NaN       NaN
# 22       NaN       NaN       NaN       NaN       NaN
# 23       NaN       NaN       NaN       NaN       NaN

# %% [markdown]
# ### Save data

# %%
#infinite
# save_file = 'regular_all_inv_Tc_uncertainty.csv'
#finite
save_file='finite_all_inv_Tc_uncertainty.csv'

df_all_inv_tc_uncert.to_csv(os.path.join(data_path,save_file),index=False)
