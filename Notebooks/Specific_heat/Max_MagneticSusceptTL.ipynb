# %% [markdown]
# ## Analysis of max susceptibility
# This notebook is for the analysis of the maxima for susceptibilities of Ising interactions many neighbors

# %%
# packages
import numpy as np
import pandas as pd
import sys
import os
import glob

# %%
# Definitions
npuntosT = 200 # Number of points in T
npuntosH = 200 # Number of points in H
Hvalue = 0
nv = 7
alpha = 2
list_interactions = 1/np.arange(1,nv)**alpha

# %%
# imports
path_import = "C:\\Users\\MHJGuillermo\\Documents\\Doctorado\\Ising\\Data\\VariosVecinos"
file_path = "SpecificHeatTLvsT_Tpoints_100_Hpoints_2_nv_3_H_0_J1_1._J2_0.25_J3_0.111111_p_2.csv"
# file_path = "SpecificHeatMaxvsT_p_5.csv"

# %%
list_files = glob.glob(path_import + '\\MagSusceptTLvsT_Tpoints_200*_p_2.csv')

# %%
list_plots = []
list_max = []
for file in list_files:
    df = pd.read_csv(os.path.join(path_import,file))
    list_plots.append(df.plot(x='k_BT/J',y='X/N'))
    list_max.append(df.loc[df['X/N'].idxmax()].values)

# %%
x = np.arange(2,8,1)
y = []
for index_max in list_max:
    y.append(index_max[0])

# %%
import matplotlib.pyplot as plt
plt.plot(x, y, 'o', color='black');

# %%
list_max
# Out:
# [array([ 0.74825996, 47.50790115]),
#  array([ 0.87767036, 47.40056156]),
#  array([ 0.97156489, 47.27851499]),
#  array([ 1.04390945, 47.14685209]),
#  array([ 1.10238047, 47.00934122]),
#  array([ 1.15146128, 46.8682704 ])]

# %%
df_export = pd.DataFrame(data=list_max,columns=['k_BT/J','X/N'])

# %% [markdown]
# Export to a file the max extracted

# %%
df_export.to_csv(path_import+'\\MagSusceptTL_max_h_0_p_2.csv')
